# %% [markdown]
# # Report
#
# ---
#
#
# ### 1. Implementations
# The report is to describe the implementations of DQN to the navigation project.

# %% [markdown]
# ### 2. Algorithm
# #### Algorithm
# The algorithm used deep Q network (DQN).
#
# #### Hyperparameters
# The eps_start for the epsilon-greedy action selection is set to 0.5 and dcay value is 0.98 to give the agent full probability to explore.
# Batch size is set to 128.
#
# #### model architectures
#
# Three hidden layer is used in the application and each has 64 nodes

# %% [markdown]
# ### 3. Plot of reward

# %%
from IPython.display import Image
from IPython.core.display import HTML
#PATH = "/Users/reblochonMasque/Documents/Drawings/"
Image(filename = "reward.png", width=400, height=400)

# %% [markdown]
# ### 4. Future ideas
# There is possible to adjust the learning step size to reduce the noises in the rewards.
